# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import pandas as pd
import time
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
# Out:
# C:\Users\Kunal\Anaconda3\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
df = pd.read_table("babyboom.dat.txt",header=None,sep="\s+",
                  names=['24hrtime','sex','weight','minutes'])
df.head()
# Out:
#    24hrtime  sex  weight  minutes
# 0         5    1    3837        5
# 1       104    1    3334       64
# 2       118    2    3554       78
# 3       155    2    3838      115
# 4       257    2    3625      177

# %%
df.minutes.mean()
# Out:
# 788.7272727272727

# %%
df.corr()
# Out:
#           24hrtime       sex    weight   minutes
# 24hrtime  1.000000  0.028027  0.075636  0.999840
# sex       0.028027  1.000000  0.228751  0.031815
# weight    0.075636  0.228751  1.000000  0.079616
# minutes   0.999840  0.031815  0.079616  1.000000

# %%
g = sns.FacetGrid(col="sex",data=df,size=8)
g.map(plt.hist,"weight")

# %% [markdown]
# # Exponential Distribution

# %%
f = lambda x,l: l*np.exp(-l*x)*(x>0)
xpts= np.arange(-2,3,0.1)
plt.plot(xpts,f(xpts,2),'o')
plt.xlabel("x")
plt.ylabel("exponential pdf")

# %%
from scipy.stats import expon
x = np.linspace(0,4,100)
colors = sns.color_palette()
lambda_ = [0.5,1,2,4]
plt.figure(figsize=(12,4))
for l,c in zip(lambda_,colors):
    plt.plot(x, expon.pdf(x,scale=1./l), lw=2,
            color=c,label="$\lambda= %.1f$"%l)
    plt.fill_between(x,expon.pdf(x,scale=1./l), color=c, alpha=.33)
    
plt.legend()
plt.ylabel("PDF at x")
plt.xlabel("x")
plt.title("Probability density function of an Exponential random variable;\
 differing $\lambda$")

# %%
from scipy.stats import expon
plt.plot(xpts, expon.pdf(xpts,scale=1./2.), 'o')
plt.hist(expon.rvs(size=1000, scale=1./2.), normed=True, alpha=0.5, bins=30)
plt.xlabel("x")
plt.ylabel("exponential pdf and samples (normalized)")

# %%
#frozen objects which can hold scale
rv= expon(scale=0.5)
plt.plot(xpts, rv.pdf(xpts), 'o')
plt.hist(rv.rvs(size=1000), normed=True, alpha=0.5, bins=30)
plt.plot(xpts, rv.cdf(xpts))
plt.xlabel("x")
plt.ylabel("exponential pdf and samples (normalized)")

# %%
timediffs = df.minutes.diff()[1:]
timediffs.hist(bins=20)

# %%
lambda_from_mean = 1./timediffs.mean()
print(lambda_from_mean, 1./lambda_from_mean)
# Out:
# 0.03006993006993007 33.25581395348837

# %%
minutes = np.arange(0,160,5)
rv = expon(scale=1./lambda_from_mean)
plt.plot(minutes, rv.pdf(minutes),'o')
timediffs.hist(normed=True, alpha=0.5)
plt.xlabel("minutes")
plt.title("Normalized data and model for estimated $\hat{\lambda}$")

# %% [markdown]
# #### An aside: The Poisson Distribution
#
# The *Poisson Distribution* is defined for all positive integers:
#
# $$P(Z=k)=\frac{\lambda^k e^{−\lambda}}{k!}, k=0,1,2,... $$

# %%
from scipy.stats import poisson
k =np.arange(15)
plt.figure(figsize=(12,8))
for i, lambda_ in enumerate([1,2,4,6]):
    plt.plot(k,poisson.pmf(k,lambda_), '-o', label=lambda_,color=colors[i])
    plt.fill_between(k,poisson.pmf(k,lambda_), color=colors[i], alpha=0.5)
    plt.legend()
plt.xlabel("$k$")
plt.ylabel("PDF at $k$")
plt.title("Poisson Distribution")

# %%
per_hour = df.minutes // 60
num_births_per_hour = df.groupby(per_hour).minutes.count()
num_births_per_hour
# Out:
# minutes
# 0     1
# 1     3
# 2     1
# 4     4
# 7     2
# 8     2
# 9     1
# 10    3
# 11    1
# 12    2
# 13    1
# 14    4
# 15    1
# 16    2
# 17    1
# 18    3
# 19    4
# 20    3
# 21    2
# 22    1
# 23    2
# Name: minutes, dtype: int64

# %%
num_births_per_hour.mean()
# Out:
# 2.0952380952380953

# %%
k = np.arange(5)
plt.figure(figsize=(12,8))
tcount=num_births_per_hour.sum()
plt.hist(num_births_per_hour, alpha=0.4,  lw=3, normed=True, label="normed hist")
sns.kdeplot(num_births_per_hour, label="kde")
plt.plot(k, poisson.pmf(k, num_births_per_hour.mean()), '-o',label="poisson")
plt.title("Baby births")
plt.xlabel("births per hour")
plt.ylabel("rate")
plt.legend();

# %%
from scipy.stats.distributions import bernoulli
def throw_a_coin(n):
    brv = bernoulli(0.5)
    return brv.rvs(size=n)

# %%
def make_throws(number_of_samples,sample_size):
    start = np.zeros((number_of_samples,sample_size), dtype=int)
    for i in range(number_of_samples):
        start[i,:]=throw_a_coin(sample_size)
    return np.mean(start,axis=1)

# %%
sample_sizes = np.arange(1,1001,1)
samples_means = [make_throws(number_of_samples=200, sample_size=i) for i in sample_sizes]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-5088b67dfacc> in <module>()
#       1 sample_sizes = np.arange(1,1001,1)
# ----> 2 samples_means = [make_throws(number_of_samples=200, sample_size=i) for i in sample_sizes]
#
# <ipython-input-22-5088b67dfacc> in <listcomp>(.0)
#       1 sample_sizes = np.arange(1,1001,1)
# ----> 2 samples_means = [make_throws(number_of_samples=200, sample_size=i) for i in sample_sizes]
#
# <ipython-input-20-d344216e8362> in make_throws(number_of_samples, sample_size)
#       2     start = np.zeros((number_of_samples,sample_size), dtype=int)
#       3     for i in range(number_of_samples):
# ----> 4         start[i,:]=throw_a_coin(sample_size)
#       5     return np.mean(start,axis=1)
#
# <ipython-input-19-218073399a5f> in throw_a_coin(n)
#       2 def throw_a_coin(n):
#       3     brv = bernoulli(0.5)
# ----> 4     return brv.rvs(size=n)
#
# C:\Users\Kunal\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, size)
#     458         kwds = self.kwds.copy()
#     459         kwds.update({'size': size})
# --> 460         return self.dist.rvs(*self.args, **kwds)
#     461
#     462     def sf(self, x):
#
# C:\Users\Kunal\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwargs)
#    2714         """
#    2715         kwargs['discrete'] = True
# -> 2716         return super(rv_discrete, self).rvs(*args, **kwargs)
#    2717
#    2718     def pmf(self, k, *args, **kwds):
#
# C:\Users\Kunal\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwds)
#     833             return loc*ones(size, 'd')
#     834
# --> 835         vals = self._rvs(*args)
#     836         if self._size is not None:
#     837             vals = reshape(vals, size)
#
# C:\Users\Kunal\Anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py in _rvs(self, p)
#     103     """
#     104     def _rvs(self, p):
# --> 105         return binom_gen._rvs(self, 1, p)
#     106
#     107     def _argcheck(self, p):
#
# C:\Users\Kunal\Anaconda3\lib\site-packages\scipy\stats\_discrete_distns.py in _rvs(self, n, p)
#      36     """
#      37     def _rvs(self, n, p):
# ---> 38         return mtrand.binomial(n, p, self._size)
#      39
#      40     def _argcheck(self, n, p):
#
# KeyboardInterrupt:

# %%
mean_of_sample_means = [np.mean(means) for mean in sample_means]
plt.plot(sample_sizes, mean_of_sample_means)
plt.ylim([0.480,0.520])

# %% [markdown]
# # Bootstraping

# %%
M_samples = 10000
N_points = timediffs.shape[0]
bs_np = np.random.choice(timediffs, size=(M_samples,N_points))
sd_mean = np.mean(bs_np,axis=1)
sd_std = np.std(bs_np,axis=1)
plt.hist(sd_mean,bins=30,normed=True,alpha=0.5,label="samples")
sns.kdeplot(sd_mean, label="inferred distribution")
plt.axvline(timediffs.mean(), 0, 1, color='r', label='Our Sample')
plt.legend()

# %% [markdown]
# # Parametric Bootstrap

# %%
rv = expon(scale=1./lambda_from_mean)
M_samples = 10000
N_points = timediffs.shape[0]
bs_p = rv.rvs(size=(M_samples,N_points))
sd_mean_p = np.mean(bs_p, axis=1)
plt.hist(sd_mean_p, bins=30, normed=True, alpha=0.5)
sns.kdeplot(sd_mean_p)
plt.axvline(timediffs.mean(), 0, 1, color='r', label='Our Sample')
